# %%
import os
import json
from openai import OpenAI
from google.colab import userdata

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=userdata.get('open_router'))

# %%
articles_folder = "/content/sample_data/"

# %%
file_path = os.path.join(articles_folder, "article 10.txt")
with open(file_path, "r", encoding="latin-1") as f:
    text = f.read()

response = client.chat.completions.create(
    model="gpt-5",
    messages=[
        {
            "role": "user",
            "content": f"Summarize this document:\n\n{text}"
        }
    ],
    max_tokens=500
)

summary = response.choices[0].message.content

# %%
print (summary)
# Out:
# - LLMs used for network defense are themselves attack targets; successful attacks can weaken defenses or compromise the host system.
# - Two key external threats:
#   - Prompt injection: Attackers hide malicious instructions in inputs (e.g., logs/traffic) to override rules or suppress alerts. Defenses include:
#     - Structured query/input separation to isolate commands from data so only authorized instructions are executed (Chen et al.).
#     - Task-specific fine-tuning of a base (non-instruction-tuned) LLM so it adheres to predefined tasks and ignores injected instructions (Piet et al.).
#   - Data poisoning: Malicious data implanted during pre-training, fine-tuning, or embedding phases introduces backdoors or degrades performance. Defenses include:
#     - Aligning an entrusted LLM’s output distribution with that of a clean small language model using KL divergence to reduce poisoned influence while preserving performance (Li et al.).
#     - Prepending carefully selected, task-matched examples (few-shot prompts) to steer interpretation and blunt backdoor effects (Mo et al.).
# - Overall: LLM-based defenses face emerging,
